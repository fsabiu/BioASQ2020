# %% [markdown]
# # Hyperparameter Tuning with the HParams

# %% [markdown]
# ### We will use HParams dashboard in TensorBoard to tune the hyperparameters for the model

# %%
import tensorflow as tf
from tensorboard.plugins.hparams import api as hp

# %% [markdown]
# #### Load the dataset

# %%
import json
from flair.data import Sentence
import progressbar
import pickle
import sys

path_dir = "/mnt/d/ASE/HLTProject/BioASQ2020"

if path_dir not in sys.path:
    sys.path.append(path_dir)

# %%
from data import load_data_yesno, generate_embeddings_yesno, generate_embeddings_yesno_pooling, load_embeddings

# %%
data=load_data_yesno("../data/training8b.json")

# %%
from flair.embeddings import ELMoEmbeddings

embeddings_elmo_pubmed = ELMoEmbeddings('pubmed')

# %%
from flair.embeddings import DocumentPoolEmbeddings, Sentence
from tensorflow.keras.layers import Dense

pooling_model = DocumentPoolEmbeddings([embeddings_elmo_pubmed])

# %%
import time
import datetime

# %%
# start = time.time()
# embeddings = generate_embeddings_yesno_pooling(pooling_model, data, "embedding_yes_no.emb")
# end = time.time()
embeddings = load_embeddings("embedding_yes_no.emb")

# %%
print(end - start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-b2ca8ee30706> in <module>
# ----> 1 print(end - start)
#
# NameError: name 'end' is not defined

# %%
import numpy as np
VALIDATION_SPLIT = 0.33

# %%
emb_numpy = np.array(embeddings)
indices = np.arange(emb_numpy.shape[0])
np.random.shuffle(indices)

# %%
# Data includes questions (0) and snippets (2)
data = emb_numpy[indices,0::2]
labels = np.array(emb_numpy[indices,1], dtype=np.float)
nb_validation_samples = int(VALIDATION_SPLIT * data.shape[0])

data = np.array([np.concatenate([el[0].data, el[1].data]) for el in data])

x_develop = data[:-nb_validation_samples]
y_develop = labels[:-nb_validation_samples]

x_train = x_develop[:-nb_validation_samples]
y_train = y_develop[:-nb_validation_samples]

# Hold out validation
x_val = x_develop[-nb_validation_samples:]
y_val = y_develop[-nb_validation_samples:]

# Hold out test
x_test = data[-nb_validation_samples:]
y_test = labels[-nb_validation_samples:]

# %% [markdown]
# ### List the hyperparameters to be tuned and their possible values

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([50, 60, 70, 80]))
HP_NUM_HIDDENS = hp.HParam('num_hiddens', hp.Discrete([1,2,3,4,5]))
HP_ACT_FUN = hp.HParam('act_fun', hp.Discrete(['sigmoid', 'tanh', 'relu']))
# HP_DROPOUT = hp.HParam('dropout', hp.RealInterval(0.1, 0.2))
# HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.1, 0.2]))
HP_OPTIMIZER = hp.HParam('optimizer', hp.Discrete(['adam', 'sgd']))


METRIC_ACCURACY = 'accuracy'

directory_results = 'logs/hparam_tuning'+ datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

with tf.summary.create_file_writer(directory_results).as_default():
  hp.hparams_config(
    hparams=[HP_NUM_UNITS, HP_NUM_HIDDENS, HP_ACT_FUN, HP_OPTIMIZER],
    metrics=[hp.Metric(METRIC_ACCURACY, display_name='Accuracy')],
  )

# %%
hparams = {
    HP_NUM_UNITS: HP_NUM_UNITS.domain.values,
    HP_NUM_HIDDENS: HP_NUM_HIDDENS.domain.values,
    HP_ACT_FUN: HP_ACT_FUN.domain.values,
    # HP_DROPOUT: HP_DROPOUT.domain.values,
    HP_OPTIMIZER: HP_OPTIMIZER.domain.values,
}

BATCH_SIZE = 32
EPOCHS = 10

# %% [markdown]
# ### We define a function that wraps the model definition (Two dense layers with a dropout in between them) and its training.

# %%
def train_test_model(hparams, logdir):
  # model = tf.keras.models.Sequential([
  #   tf.keras.layers.Flatten(),
  #   tf.keras.layers.Dense(hparams[HP_NUM_UNITS], activation=tf.nn.relu),
  #   tf.keras.layers.Dropout(hparams[HP_DROPOUT]),
  #   tf.keras.layers.Dense(10, activation=tf.nn.softmax),
  # ])
  model = tf.keras.models.Sequential()
  for i in range(hparams[HP_NUM_HIDDENS]):
    model.add(Dense(hparams[HP_NUM_UNITS], activation = hparams[HP_ACT_FUN]))

  model.compile(
      optimizer=hparams[HP_OPTIMIZER],
      loss='sparse_categorical_crossentropy',
      metrics=['accuracy'],
  )

  model.fit(x_train, y_train, 
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_val, y_val),
    callbacks=[
            tf.keras.callbacks.TensorBoard(logdir),  # log metrics
            hp.KerasCallback(logdir, hparams),  # log hparams
        ]) # Run with 1 epoch to speed things up for demo purposes

  _, accuracy = model.evaluate(x_val, y_val)
  
  return accuracy

# %%
result = train_test_model(params_list[0], 'logs/hparam_tuning20200614-192023')

# %%
result
# Out:
# [0.6931496262550354, 0.7862069010734558]

# %% [markdown]
# ### For each run, log an hparams summary with the hyperparameters and final accuracy:

# %% [markdown]
# ### Now we can run the experiments. Results are reported in the log directory

# %%
from itertools import product

# %%
def grid_search(grid_params, inputs = None, targets = None):
    '''
        grid_search function.
        It performs a grid search using the given parameters.
        It reports result on a file

        Parameters
        ----------
        - grid_params: A dictionary containing the parameters to test
        - inputs: A list containing the neural network inputs 
        - targets: A list containing the neural network targets 

        Returns
        -------
        - min_error: The minimum error obtained
        - best_params: The best hyperparameters
    '''
    
    keys, values = zip(*grid_params.items())
    params_list = [dict(zip(keys, v)) for v in product(*values)]
    print(len(params_list))
    
    for session_num, hparams in enumerate(params_list):
        run_name = "run-%d" % session_num
        print('--- Starting trial: %s' % run_name)

        print({h.name: hparams[h] for h in hparams})
        
        # run_dir = 'logs/hparam_tuning/' + run_name
        run_dir = directory_results + "/"+ run_name
        hp.hparams(hparams)  # record the values used in this trial
        accuracy = train_test_model(hparams, run_dir)

# %%
start = time.time()
grid_search(hparams)
end = time.time()
# Out:
# =========] - 0s 27ms/step - loss: 3.1579 - accuracy: 0.8040 - val_loss: 3.3954 - val_accuracy: 0.7897
# Epoch 7/10
# 10/10 [==============================] - 0s 19ms/step - loss: 3.1573 - accuracy: 0.8040 - val_loss: 3.3955 - val_accuracy: 0.7897
# Epoch 8/10
# 10/10 [==============================] - 0s 29ms/step - loss: 3.1571 - accuracy: 0.8040 - val_loss: 3.3954 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 17ms/step - loss: 3.1570 - accuracy: 0.8040 - val_loss: 3.3955 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 15ms/step - loss: 3.1569 - accuracy: 0.8040 - val_loss: 3.3950 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 3ms/step - loss: 3.3950 - accuracy: 0.7897
# --- Starting trial: run-108
# 10/10 [==============================] - 0s 16ms/step - loss: 3.7202 - accuracy: 0.8040 - val_loss: 3.7144 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 3ms/step - loss: 3.7144 - accuracy: 0.7897
# --- Starting trial: run-112
# {'num_units': 80, 'num_hiddens': 4, 'act_fun': 'tanh', 'optimizer': 'adam'}
# Epoch 1/10
# 10/10 [==============================] - 0s 29ms/step - loss: 3.0228 - accuracy: 0.6910 - val_loss: 1.0323 - val_accuracy: 0.7897
# Epoch 2/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6907 - accuracy: 0.8040 - val_loss: 0.9857 - val_accuracy: 0.7897
# Epoch 3/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5399 - accuracy: 0.8040 - val_loss: 0.5221 - val_accuracy: 0.7897
# Epoch 4/10
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5648 - accuracy: 0.8040 - val_loss: 0.5616 - val_accuracy: 0.7897
# Epoch 5/10
# 10/10 [==============================] - 0s 12ms/step - loss: 0.6839 - accuracy: 0.8040 - val_loss: 0.5657 - val_accuracy: 0.7897
# Epoch 6/10
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6392 - accuracy: 0.8140 - val_loss: 0.6878 - val_accuracy: 0.6483
# Epoch 7/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.6837 - accuracy: 0.7708 - val_loss: 0.6844 - val_accuracy: 0.7793
# Epoch 8/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6792 - accuracy: 0.8173 - val_loss: 0.6783 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6700 - accuracy: 0.8140 - val_loss: 0.6652 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6442 - accuracy: 0.8040 - val_loss: 0.6242 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6242 - accuracy: 0.7897
# --- Starting trial: run-113
# {'num_units': 80, 'num_hiddens': 4, 'act_fun': 'tanh', 'optimizer': 'sgd'}
# Epoch 1/10
# 10/10 [==============================] - 0s 25ms/step - loss: 2.7834 - accuracy: 0.7309 - val_loss: 1.6037 - val_accuracy: 0.7897
# Epoch 2/10
# 10/10 [==============================] - 0s 13ms/step - loss: 1.0079 - accuracy: 0.8073 - val_loss: 0.6686 - val_accuracy: 0.7897
# Epoch 3/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5917 - accuracy: 0.8040 - val_loss: 0.7727 - val_accuracy: 0.7897
# Epoch 4/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6456 - accuracy: 0.8040 - val_loss: 0.5960 - val_accuracy: 0.7897
# Epoch 5/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5147 - accuracy: 0.8040 - val_loss: 0.7017 - val_accuracy: 0.7897
# Epoch 6/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.6825 - accuracy: 0.8073 - val_loss: 0.6766 - val_accuracy: 0.7897
# Epoch 7/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6634 - accuracy: 0.8040 - val_loss: 0.6505 - val_accuracy: 0.7897
# Epoch 8/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.5925 - accuracy: 0.8040 - val_loss: 0.5081 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 11ms/step - loss: 0.6045 - accuracy: 0.8040 - val_loss: 0.6267 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 12ms/step - loss: 0.6461 - accuracy: 0.8040 - val_loss: 3.0091 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 7ms/step - loss: 3.0091 - accuracy: 0.7897
# --- Starting trial: run-114
# {'num_units': 80, 'num_hiddens': 5, 'act_fun': 'relu', 'optimizer': 'adam'}
# Epoch 1/10
# 10/10 [==============================] - 0s 30ms/step - loss: 3.1402 - accuracy: 0.5515 - val_loss: 2.1554 - val_accuracy: 0.7897
# Epoch 2/10
# 10/10 [==============================] - 0s 15ms/step - loss: 1.7720 - accuracy: 0.7874 - val_loss: 1.3039 - val_accuracy: 0.5448
# Epoch 3/10
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9521 - accuracy: 0.3090 - val_loss: 0.7120 - val_accuracy: 0.2103
# Epoch 4/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6962 - accuracy: 0.1960 - val_loss: 0.6932 - val_accuracy: 0.2103
# Epoch 5/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6930 - accuracy: 0.1960 - val_loss: 0.6932 - val_accuracy: 0.2103
# Epoch 6/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.6928 - accuracy: 0.1960 - val_loss: 0.6932 - val_accuracy: 0.2103
# Epoch 7/10
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6921 - accuracy: 0.1960 - val_loss: 0.6948 - val_accuracy: 0.2103
# Epoch 8/10
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6912 - accuracy: 0.1960 - val_loss: 0.6933 - val_accuracy: 0.2103
# Epoch 9/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.6905 - accuracy: 0.1960 - val_loss: 0.6957 - val_accuracy: 0.2103
# Epoch 10/10
# 10/10 [==============================] - 0s 22ms/step - loss: 0.6898 - accuracy: 0.1960 - val_loss: 0.6935 - val_accuracy: 0.2103
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6935 - accuracy: 0.2103
# --- Starting trial: run-115
# {'num_units': 80, 'num_hiddens': 5, 'act_fun': 'relu', 'optimizer': 'sgd'}
# Epoch 1/10
# 10/10 [==============================] - 0s 29ms/step - loss: 5.4620 - accuracy: 0.7143 - val_loss: 4.6216 - val_accuracy: 0.7897
# Epoch 2/10
# 10/10 [==============================] - 0s 17ms/step - loss: 3.6491 - accuracy: 0.8040 - val_loss: 2.0616 - val_accuracy: 0.7586
# Epoch 3/10
# 10/10 [==============================] - 0s 16ms/step - loss: 1.0546 - accuracy: 0.8040 - val_loss: 0.6336 - val_accuracy: 0.7897
# Epoch 4/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5209 - accuracy: 0.8040 - val_loss: 0.5196 - val_accuracy: 0.7897
# Epoch 5/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4649 - accuracy: 0.8040 - val_loss: 0.5938 - val_accuracy: 0.7897
# Epoch 6/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4301 - accuracy: 0.8040 - val_loss: 0.7371 - val_accuracy: 0.7897
# Epoch 7/10
# 10/10 [==============================] - 0s 12ms/step - loss: 0.3930 - accuracy: 0.8040 - val_loss: 2.3009 - val_accuracy: 0.7897
# Epoch 8/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4840 - accuracy: 0.8040 - val_loss: 0.5187 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.3666 - accuracy: 0.8040 - val_loss: 0.6498 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 12ms/step - loss: 0.3405 - accuracy: 0.8073 - val_loss: 0.5798 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5798 - accuracy: 0.7897
# --- Starting trial: run-116
# {'num_units': 80, 'num_hiddens': 5, 'act_fun': 'sigmoid', 'optimizer': 'adam'}
# Epoch 1/10
# 10/10 [==============================] - 0s 40ms/step - loss: 4.0797 - accuracy: 0.2060 - val_loss: 3.7870 - val_accuracy: 0.7897
# Epoch 2/10
# 10/10 [==============================] - 0s 16ms/step - loss: 3.6022 - accuracy: 0.8040 - val_loss: 3.3699 - val_accuracy: 0.7897
# Epoch 3/10
# 10/10 [==============================] - 0s 20ms/step - loss: 3.1805 - accuracy: 0.8040 - val_loss: 2.9069 - val_accuracy: 0.7897
# Epoch 4/10
# 10/10 [==============================] - 0s 22ms/step - loss: 2.6613 - accuracy: 0.8040 - val_loss: 2.2975 - val_accuracy: 0.7897
# Epoch 5/10
# 10/10 [==============================] - 0s 18ms/step - loss: 2.0055 - accuracy: 0.8040 - val_loss: 1.6167 - val_accuracy: 0.7897
# Epoch 6/10
# 10/10 [==============================] - 0s 24ms/step - loss: 1.3804 - accuracy: 0.8040 - val_loss: 1.1163 - val_accuracy: 0.7897
# Epoch 7/10
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9967 - accuracy: 0.8040 - val_loss: 0.8765 - val_accuracy: 0.7897
# Epoch 8/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.8219 - accuracy: 0.8040 - val_loss: 0.7645 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7249 - accuracy: 0.8040 - val_loss: 0.6785 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 24ms/step - loss: 0.6375 - accuracy: 0.8040 - val_loss: 0.6015 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6015 - accuracy: 0.7897
# --- Starting trial: run-117
# {'num_units': 80, 'num_hiddens': 5, 'act_fun': 'sigmoid', 'optimizer': 'sgd'}
# Epoch 1/10
# 10/10 [==============================] - 0s 30ms/step - loss: 4.1017 - accuracy: 0.0000e+00 - val_loss: 3.9902 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 10/10 [==============================] - 0s 12ms/step - loss: 3.9397 - accuracy: 0.0000e+00 - val_loss: 3.8853 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 10/10 [==============================] - 0s 12ms/step - loss: 3.8561 - accuracy: 0.5714 - val_loss: 3.8252 - val_accuracy: 0.7897
# Epoch 4/10
# 10/10 [==============================] - 0s 11ms/step - loss: 3.8052 - accuracy: 0.8040 - val_loss: 3.7849 - val_accuracy: 0.7897
# Epoch 5/10
# 10/10 [==============================] - 0s 13ms/step - loss: 3.7697 - accuracy: 0.8040 - val_loss: 3.7549 - val_accuracy: 0.7897
# Epoch 6/10
# 10/10 [==============================] - 0s 12ms/step - loss: 3.7424 - accuracy: 0.8040 - val_loss: 3.7308 - val_accuracy: 0.7897
# Epoch 7/10
# 10/10 [==============================] - 0s 14ms/step - loss: 3.7200 - accuracy: 0.8040 - val_loss: 3.7103 - val_accuracy: 0.7897
# Epoch 8/10
# 10/10 [==============================] - 0s 36ms/step - loss: 3.7007 - accuracy: 0.8040 - val_loss: 3.6922 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 19ms/step - loss: 3.6835 - accuracy: 0.8040 - val_loss: 3.6760 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 16ms/step - loss: 3.6679 - accuracy: 0.8040 - val_loss: 3.6609 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 4ms/step - loss: 3.6609 - accuracy: 0.7897
# --- Starting trial: run-118
# {'num_units': 80, 'num_hiddens': 5, 'act_fun': 'tanh', 'optimizer': 'adam'}
# Epoch 1/10
# 10/10 [==============================] - 0s 40ms/step - loss: 5.5110 - accuracy: 0.7076 - val_loss: 2.3387 - val_accuracy: 0.7897
# Epoch 2/10
# 10/10 [==============================] - 0s 16ms/step - loss: 1.9183 - accuracy: 0.8040 - val_loss: 1.3425 - val_accuracy: 0.7897
# Epoch 3/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9850 - accuracy: 0.8040 - val_loss: 0.6267 - val_accuracy: 0.7897
# Epoch 4/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5984 - accuracy: 0.8040 - val_loss: 0.5907 - val_accuracy: 0.7897
# Epoch 5/10
# 10/10 [==============================] - 0s 30ms/step - loss: 0.5776 - accuracy: 0.8040 - val_loss: 0.5683 - val_accuracy: 0.7897
# Epoch 6/10
# 10/10 [==============================] - 0s 16ms/step - loss: 0.5490 - accuracy: 0.8040 - val_loss: 0.5382 - val_accuracy: 0.7897
# Epoch 7/10
# 10/10 [==============================] - 0s 24ms/step - loss: 0.5122 - accuracy: 0.8040 - val_loss: 0.5076 - val_accuracy: 0.7897
# Epoch 8/10
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4933 - accuracy: 0.8040 - val_loss: 0.5100 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4867 - accuracy: 0.8040 - val_loss: 0.5050 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4830 - accuracy: 0.8040 - val_loss: 0.5018 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5018 - accuracy: 0.7897
# --- Starting trial: run-119
# {'num_units': 80, 'num_hiddens': 5, 'act_fun': 'tanh', 'optimizer': 'sgd'}
# Epoch 1/10
# 10/10 [==============================] - 0s 37ms/step - loss: 2.9417 - accuracy: 0.7110 - val_loss: 1.6818 - val_accuracy: 0.7897
# Epoch 2/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.8380 - accuracy: 0.8040 - val_loss: 0.8364 - val_accuracy: 0.2724
# Epoch 3/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6929 - accuracy: 0.7010 - val_loss: 0.6372 - val_accuracy: 0.7897
# Epoch 4/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.5673 - accuracy: 0.8040 - val_loss: 0.5408 - val_accuracy: 0.7897
# Epoch 5/10
# 10/10 [==============================] - 0s 20ms/step - loss: 0.4569 - accuracy: 0.8040 - val_loss: 0.5723 - val_accuracy: 0.7897
# Epoch 6/10
# 10/10 [==============================] - 0s 14ms/step - loss: 0.4953 - accuracy: 0.8040 - val_loss: 1.1642 - val_accuracy: 0.7897
# Epoch 7/10
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6029 - accuracy: 0.8007 - val_loss: 0.6647 - val_accuracy: 0.7897
# Epoch 8/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.6083 - accuracy: 0.8040 - val_loss: 0.5143 - val_accuracy: 0.7897
# Epoch 9/10
# 10/10 [==============================] - 0s 15ms/step - loss: 0.4520 - accuracy: 0.8040 - val_loss: 0.6094 - val_accuracy: 0.7897
# Epoch 10/10
# 10/10 [==============================] - 0s 17ms/step - loss: 0.4673 - accuracy: 0.8040 - val_loss: 2.2764 - val_accuracy: 0.7897
# 10/10 [==============================] - 0s 3ms/step - loss: 2.2764 - accuracy: 0.7897

# %%
keys, values = zip(*hparams.items())
params_list = [dict(zip(keys, v)) for v in product(*values)]
print(len(params_list))
print(end - start)
# Out:
# 120
# 265.37332463264465

# %% [markdown]
# ### Visualize results in tensorboard

# %%
# The command is the following:
# tensorboard --logdir _test/logs/hparam_tuning

# %%
directory_results
# Out:
# 'logs/hparam_tuning20200614-192023'

# %%
# !tensorboard --logdir logs/hparam_tuning20200614-192023
# Out:
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.2.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
